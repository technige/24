# %%
from __future__ import print_function

from py2neo.neo4j import *


graph = GraphDatabaseService()
for char in graph.find("Character"):
    print(char["name"])
# Out:
# ERROR:py2neo.packages.httpstream.http:!!! SocketError: Connection refused
# ---------------------------------------------------------------------------
# SocketError                               Traceback (most recent call last)
# <ipython-input-17-43b7a61f33f9> in <module>()
#       4
#       5
# ----> 6 graph = GraphDatabaseService()
#       7 for char in graph.find("Character"):
#       8     print(char["name"])
#
# /Users/markneedham/projects/24/24/lib/python2.7/site-packages/py2neo/neo4j.pyc in __init__(self, uri)
#     534     def __init__(self, uri=None):
#     535         if uri is None:
# --> 536             uri = ServiceRoot().graph_db.__uri__
#     537         Resource.__init__(self, uri)
#     538         self._indexes = {Node: {}, Relationship: {}}
#
# /Users/markneedham/projects/24/24/lib/python2.7/site-packages/py2neo/neo4j.pyc in graph_db(self)
#     460     @property
#     461     def graph_db(self):
# --> 462         return GraphDatabaseService.get_instance(self.__metadata__["data"])
#     463
#     464     @property
#
# /Users/markneedham/projects/24/24/lib/python2.7/site-packages/py2neo/neo4j.pyc in __metadata__(self)
#     336     def __metadata__(self):
#     337         if not self._metadata:
# --> 338             self.refresh()
#     339         return self._metadata
#     340
#
# /Users/markneedham/projects/24/24/lib/python2.7/site-packages/py2neo/neo4j.pyc in refresh(self)
#     358         """
#     359         if not self.is_abstract:
# --> 360             self._metadata = ResourceMetadata(self._get().content)
#     361
#     362     def _get(self):
#
# /Users/markneedham/projects/24/24/lib/python2.7/site-packages/py2neo/neo4j.pyc in _get(self)
#     363         try:
#     364             return self._resource.get(headers=self._headers,
# --> 365                                       product=self._product)
#     366         except _ClientError as e:
#     367             raise ClientError(e)
#
# /Users/markneedham/projects/24/24/lib/python2.7/site-packages/py2neo/packages/httpstream/http.pyc in get(self, headers, redirect_limit, **kwargs)
#     801         """
#     802         rq = Request("GET", self._uri, None, headers)
# --> 803         return rq.submit(redirect_limit=redirect_limit, **kwargs)
#     804
#     805     def put(self, body=None, headers=None, **kwargs):
#
# /Users/markneedham/projects/24/24/lib/python2.7/site-packages/py2neo/packages/httpstream/http.pyc in submit(self, redirect_limit, product, **response_kwargs)
#     386         headers.setdefault("User-Agent", user_agent(product))
#     387         while True:
# --> 388             http, rs = submit(self.method, uri, self.body, headers)
#     389             status_class = rs.status // 100
#     390             if status_class == 3:
#
# /Users/markneedham/projects/24/24/lib/python2.7/site-packages/py2neo/packages/httpstream/http.pyc in submit(method, uri, body, headers)
#     326                                       host_port=uri.host_port)
#     327         else:
# --> 328             raise SocketError(code, description, host_port=uri.host_port)
#     329     else:
#     330         return http, response
#
# SocketError: Connection refused

# %%
from __future__ import print_function
from py2neo.neo4j import *

graph_db = GraphDatabaseService()

q = """\
MATCH (c:Character)-[a:APPEARED_IN]->(season)
RETURN c.name, sum(a.episodes) AS episodes, collect(season.name)
ORDER BY episodes DESC
"""

query = CypherQuery(graph_db, q)

for record in query.execute():
    print(record)
# Out:
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Jack Bauer', 202, [u'Season 1', u'Season 2', u'Season 3', u'Season 4', u'Season 5', u'Season 6', u'Season 7', u'Season 8', u'Season 9']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u"Chloe O'Brian", 135, [u'Season 3', u'Season 4', u'Season 5', u'Season 6', u'Season 7', u'Season 8', u'Season 9']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Anthony "Tony" Almeida', 115, [u'Season 1', u'Season 2', u'Season 3', u'Season 4', u'Season 5', u'Season 7']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Kim Bauer', 79, [u'Season 1', u'Season 2', u'Season 3', u'Season 5', u'Season 7', u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'David Palmer', 79, [u'Season 1', u'Season 2', u'Season 3', u'Season 4', u'Season 5']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Bill Buchanan', 64, [u'Season 4', u'Season 5', u'Season 6', u'Season 7']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Michelle Dessler', 62, [u'Season 2', u'Season 3', u'Season 4', u'Season 5']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'
[u'Season 6']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'James Prescott', 8, [u'Season 2', u'Season 3']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Patty Brooks', 8, [u'Season 1']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Jamot', 8, [u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Graem Bauer', 8, [u'Season 5', u'Season 6']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Farhad Hassan', 8, [u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Richard Heller', 7, [u'Season 4']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Alexis Drazen', 7, [u'Season 1']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Brian Gedge', 7, [u'Season 7']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Coburn', 7, [u'Season 9']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Sergei Bazhaev', 7, [u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Marianne Taylor', 7, [u'Season 4']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Greg Seaton', 7, [u'Season 7']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Gary Matheson', 7, [u'Season 2']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Julia Milliken', 7, [u'Season 3']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Mandy', 7, [u'Season 1', u'Season 2', u'Season 4']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Ron Clark', 7, [u'Season 9']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Hamri Al-Assad', 7, [u'Season 6']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Mikhail Novakovich', 7, [u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Miguel', 7, [u'Season 2']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Simone Al-Harazi', 7, [u'Season 9']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Ian Al-Harazi', 7, [u'Season 9']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Alastair Davies', 7, [u'Season 9']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Ivan Erwich', 6, [u'Season 5']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Hal Gardner', 6, [u'Season 5']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Nick Coughlin', 6, [u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Alberta Green', 6, [u'Season 1']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Spenser Wolff', 6, [u'Season 5']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Diane Huxley', 6, [u'Season 5']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Yusuf Auda', 6, [u'Season 2']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Kyle Singer', 6, [u'Season 3']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Melanie', 6, [u'Season 1']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Blaine Mayer', 6, [u'Season 7']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Josef Bazhaev', 6, [u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Ule Matobo', 6, [u'Season 7']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Arthur Welton', 6, [u'Season 6']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Owen', 6, [u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Cara Bowden', 6, [u'Season 7']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Meredith Reed', 6, [u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Dan Mounts', 6, [u'Season 1']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Janet York', 6, [u'Season 1']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Nabeel', 6, [u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Walid Al-Rezani', 6, [u'Season 6']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Elijah Timothy Stram', 6, [u'Season 1']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Derek Huxley', 6, [u'Season 5']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Nicole Palmer', 6, [u'Season 1']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'James Nathanson', 6, [u'Season 5']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Anya Suvarov', 6, [u'Season 5', u'Season 6']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'David Emerson', 5, [u'Season 7']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Jenny Dodge', 5, [u'Season 2']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Erika', 5, [u'Season 7']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Samantha Roth', 5, [u'Season 7']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Omar', 5, [u'Season 4']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Ali', 5, [u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Jane Saunders', 5, [u'Season 3']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Linda', 5, [u'Season 3']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Syed Ali', 5, [u'Season 2']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Nicole Duncan', 5, [u'Season 3']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Paula Schaeffer', 5, [u'Season 2']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Marcus Frederick Alvers', 5, [u'Season 3']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Victor Drazen', 5, [u'Season 1']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Maya Driscoll', 5, [u'Season 4']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Alan Wilson', 5, [u'Season 7']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Shari Rothenberg', 5, [u'Season 5']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Edward Vossler', 4, [u'Season 7']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Samuels', 4, [u'Season 6']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Osterlind', 4, [u'Season 3']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Alan Milliken', 4, [u'Season 3']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Ray Wallace', 4, [u'Season 6']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Craig Phillips', 4, [u'Season 3']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Phil Parslow', 4, [u'Season 1']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Ostroff', 4, [u'Season 5']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Robert Galvez', 4, [u'Season 7']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Carla Matheson', 4, [u'Season 2']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Stephen', 4, [u'Season 7', u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Eric Rayburn', 4, [u'Season 2']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Helen Singer', 4, [u'Season 3']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Peter Kingsley', 4, [u'Season 2']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Scott Wallace', 4, [u'Season 6']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Rita Brady', 4, [u'Season 6']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Jillian Wallace', 4, [u'Season 6']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Jim Ricker', 4, [u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Davros', 4, [u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Oleg Bazhaev', 4, [u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Elizabeth Nash', 4, [u'Season 1']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Darren McCarthy', 4, [u'Season 6']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Pavel Tokarev', 4, [u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Naveed Shabazz', 4, [u'Season 9']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Dan', 4, [u'Season 6']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Ahmed Amar', 4, [u'Season 6']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Hal Turner', 4, [u'Season 6']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Marika Donoso', 4, [u'Season 7']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Debbie Pendleton', 4, [u'Season 4']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Chris Tanner', 4, [u'Season 9']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Ron Wieland', 4, [u'Season 2']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Andrew Paige', 3, [u'Season 4']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Mark Bishop', 3, [u'Season 6']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Anatol Stolnavich', 3, [u'Season 9']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Bill Prady', 3, [u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Derrick Yates', 3, [u'Season 9']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Lonnie McRae', 3, [u'Season 2']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Dimitri', 3, [u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Eddie Grant', 3, [u'Season 2']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Vladimir Laitanan', 3, [u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Luis Annicon', 3, [u'Season 3']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Benjamin Juma', 3, [u'Season 7']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Michael Latham', 3, [u'Season 7']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Jibraan Al-Zarian', 3, [u'Season 7']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Collette Stenger', 3, [u'Season 5']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Marcos Al-Zacar', 3, [u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Muhtadi Gohar', 3, [u'Season 7']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Barry Landes', 2, [u'Season 5']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Alex Hewitt', 2, [u'Season 2']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Ted Cofell', 2, [u'Season 1']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Max', 2, [u'Season 2']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Mark Bledsoe', 2, [u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Elaine Al-Zacar', 2, [u'Season 8']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Robert Ellis', 2, [u'Season 1']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Mark DeSalvo', 2, [u'Season 1']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Richard Walsh', 2, [u'Season 1']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Anatoly Markov', 2, [u'Season 6']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Dave Conlon', 2, [u'Season 4']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Theo Stoller', 2, [u'Season 5']))
# Record(columns=(u'c.name', u'episodes', u'collect(season.name)'), values=(u'Bridgit', 2, [u'Season 1']))
